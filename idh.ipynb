# %% [markdown]
# # Detalles
#
# Dropear todas las entradas que no correspondan a años de juegos olimpicos???. Tal vez sea interesante detallar como es el crecimiento del pais y su relacion con el incremento o descenso de obtencion de medallas, cantidad de atletas, etc, por lo que puede que no sea conveniente eliminar esas entradas.
#
# Lo que si seria importante es unir todo en un dataset unico.

# %% [markdown]
# # Comentarios
#
# Los dataset corresponden a 9 pero yo creo que los relevantes para el caso de estudio en conjunto con los de las olimpiadas son los siguientes:
# - expected-years-of-schooling.csv
# - gross-national-income-per-capita.csv
# - human-development-index.csv
# - hdi-vs-hihd.csv | Este ofrece la cantidad de poblacion del pais, por eso creo que es relevante. el hihd la verdad no se que aporta de distinto referente al hdi.
#
# hdi: Human developmen index -> indice de desarrollo humano.
#
#
# hihd: historical index of human development -> indice historico del desarrollo humano.
#
# Los otros ofrecen tambien otras mediciones pero creo que estos son los principales ya que ofrecen todas las mediciones necesarias.
#
# **Parece ser que el hihd es el indice de desarrollo humano por desigualdad, faltaria investigar ya que segun lo que he buscado el ahdi es lo que corresponde al por desigualdad. pero el hihd tiene una columna llamada prados de escosura.

# %%
# !pip install pycountry_convert

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
schooling_data = pd.read_csv("IDH/expected-years-of-schooling.csv")
national_income_data = pd.read_csv("IDH/gross-national-income-per-capita.csv")
hdi_data = pd.read_csv("IDH/human-development-index.csv")
hihd_data = pd.read_csv("IDH/hdi-vs-hihd.csv")

# %% [markdown]
# ## Union de las columnas mas importantes de los dataframes

# %%
data_merged = schooling_data.merge(national_income_data[['Year', 'Code', 'GNI per capita, PPP (constant 2017 international $)']], on=['Year', 'Code'], how='left')
data_merged = data_merged.merge(hdi_data[['Year', 'Code', 'Human Development Index (UNDP)']], on=['Year', 'Code'], how='left')
data_merged = data_merged.merge(hihd_data[['Year', 'Code', 'Population (historical estimates)']], on=['Year', 'Code'], how='left')

#data_merged = data_merged.merge(hihd_data[['Year', 'Code', 'Historical Index of Human Development (Prados de la Escosura)']], on=['Year', 'Code'], how='left')

#data_merged = data_merged.merge(hihd_data[['Year', 'Code', 'Continent']], on=['Year', 'Code'], how='left')


data_merged
# Out:
#             Entity Code  Year  Expected Years of Schooling (years)  \
# 0      Afghanistan  AFG  1990                                  2.6
# 1      Afghanistan  AFG  1991                                  2.9
# 2      Afghanistan  AFG  1992                                  3.2
# 3      Afghanistan  AFG  1993                                  3.6
# 4      Afghanistan  AFG  1994                                  3.9
# ...            ...  ...   ...                                  ...
# 11023     Zimbabwe  ZWE  2013                                 10.2
# 11024     Zimbabwe  ZWE  2014                                 10.3
# 11025     Zimbabwe  ZWE  2015                                 10.3
# 11026     Zimbabwe  ZWE  2016                                 10.3
# 11027     Zimbabwe  ZWE  2017                                 10.3
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11023                                        2875.757148
# 11024                                        2901.298513
# 11025                                        2858.616749
# 11026                                        2884.156050
# 11027                                        3207.887558
#
#        Human Development Index (UNDP)  Population (historical estimates)
# 0                                 NaN                         12412311.0
# 1                                 NaN                         13299016.0
# 2                                 NaN                         14485543.0
# 3                                 NaN                         15816601.0
# 4                                 NaN                         17075728.0
# ...                               ...                                ...
# 11023                           0.516                         13350378.0
# 11024                           0.525                         13586710.0
# 11025                           0.529                         13814642.0
# 11026                           0.532                         14030338.0
# 11027                           0.535                         14236599.0
#
# [11028 rows x 7 columns]

# %%
import pycountry_convert as pc

# Lista de países
lista_codigos_paises = [
    'AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT',
    'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BTN',
    'BOL', 'BIH', 'BWA', 'BRA', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR',
    'CAN', 'CPV', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COG', 'CRI',
    'CIV', 'HRV', 'CUB', 'CYP', 'CZE', 'COD', 'DNK', 'DJI', 'DMA', 'DOM',
    'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'FJI', 'FIN',
    'FRA', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GRD', 'GTM', 'GIN',
    'GNB', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN',
    'IRQ', 'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR', 'KAZ', 'KEN', 'KIR',
    'KWT', 'KGZ', 'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU',
    'LUX', 'MDG', 'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MHL', 'MRT', 'MUS',
    'MEX', 'MDA', 'MNG', 'MNE', 'MAR', 'MOZ', 'MMR', 'NAM', 'NRU', 'NPL',
    'NLD', 'NZL', 'NIC', 'NER', 'NGA', 'PRK', 'MKD', 'NOR', 'OMN', 'PAK',
    'PLW', 'PSE', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'QAT',
    'ROU', 'RUS', 'RWA', 'KNA', 'LCA', 'VCT', 'WSM', 'SMR', 'STP', 'SAU',
    'SEN', 'SRB', 'SYC', 'SLE', 'SGP', 'SVK', 'SVN', 'SLB', 'ZAF', 'KOR',
    'SSD', 'ESP', 'LKA', 'SDN', 'SUR', 'SWE', 'CHE', 'SYR', 'TJK', 'TZA',
    'THA', 'TLS', 'TGO', 'TON', 'TTO', 'TUN', 'TUR', 'TKM', 'TUV', 'UGA',
    'UKR', 'ARE', 'GBR', 'USA', 'URY', 'UZB', 'VUT', 'VEN', 'VNM', 'YEM',
    'ZMB', 'ZWE'
]


# Crear un diccionario donde cada clave sea el código del país y su valor sea el continente
diccionario_continentes = {}
for pais in lista_codigos_paises:
    try:
        alpha2 = pc.country_alpha3_to_country_alpha2(pais)
        country_continent_code = pc.country_alpha2_to_continent_code(alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)

        diccionario_continentes[pais] = country_continent_name
    except LookupError:
        print(f"No se pudo encontrar información sobre el continente para el país: {pais}")

# Imprimir el diccionario resultante
print(diccionario_continentes)
# Out:
# No se pudo encontrar información sobre el continente para el país: TLS
# {'AFG': 'Asia', 'ALB': 'Europe', 'DZA': 'Africa', 'AND': 'Europe', 'AGO': 'Africa', 'ATG': 'North America', 'ARG': 'South America', 'ARM': 'Asia', 'AUS': 'Oceania', 'AUT': 'Europe', 'AZE': 'Asia', 'BHS': 'North America', 'BHR': 'Asia', 'BGD': 'Asia', 'BRB': 'North America', 'BLR': 'Europe', 'BEL': 'Europe', 'BLZ': 'North America', 'BEN': 'Africa', 'BTN': 'Asia', 'BOL': 'South America', 'BIH': 'Europe', 'BWA': 'Africa', 'BRA': 'South America', 'BRN': 'Asia', 'BGR': 'Europe', 'BFA': 'Africa', 'BDI': 'Africa', 'KHM': 'Asia', 'CMR': 'Africa', 'CAN': 'North America', 'CPV': 'Africa', 'CAF': 'Africa', 'TCD': 'Africa', 'CHL': 'South America', 'CHN': 'Asia', 'COL': 'South America', 'COM': 'Africa', 'COG': 'Africa', 'CRI': 'North America', 'CIV': 'Africa', 'HRV': 'Europe', 'CUB': 'North America', 'CYP': 'Asia', 'CZE': 'Europe', 'COD': 'Africa', 'DNK': 'Europe', 'DJI': 'Africa', 'DMA': 'North America', 'DOM': 'North America', 'ECU': 'South America', 'EGY': 'Africa', 'SLV': 'North America', 'GNQ': 'Africa', 'ERI': 'Africa', 'EST': 'Europe', 'SWZ': 'Africa', 'ETH': 'Africa', 'FJI': 'Oceania', 'FIN': 'Europe', 'FRA': 'Europe', 'GAB': 'Africa', 'GMB': 'Africa', 'GEO': 'Asia', 'DEU': 'Europe', 'GHA': 'Africa', 'GRC': 'Europe', 'GRD': 'North America', 'GTM': 'North America', 'GIN': 'Africa', 'GNB': 'Africa', 'GUY': 'South America', 'HTI': 'North America', 'HND': 'North America', 'HKG': 'Asia', 'HUN': 'Europe', 'ISL': 'Europe', 'IND': 'Asia', 'IDN': 'Asia', 'IRN': 'Asia', 'IRQ': 'Asia', 'IRL': 'Europe', 'ISR': 'Asia', 'ITA': 'Europe', 'JAM': 'North America', 'JPN': 'Asia', 'JOR': 'Asia', 'KAZ': 'Asia', 'KEN': 'Africa', 'KIR': 'Oceania', 'KWT': 'Asia', 'KGZ': 'Asia', 'LAO': 'Asia', 'LVA': 'Europe', 'LBN': 'Asia', 'LSO': 'Africa', 'LBR': 'Africa', 'LBY': 'Africa', 'LIE': 'Europe', 'LTU': 'Europe', 'LUX': 'Europe', 'MDG': 'Africa', 'MWI': 'Africa', 'MYS': 'Asia', 'MDV': 'Asia', 'MLI': 'Africa', 'MLT': 'Europe', 'MHL': 'Oceania', 'MRT': 'Africa', 'MUS': 'Africa', 'MEX': 'North America', 'MDA': 'Europe', 'MNG': 'Asia', 'MNE': 'Europe', 'MAR': 'Africa', 'MOZ': 'Africa', 'MMR': 'Asia', 'NAM': 'Africa', 'NRU': 'Oceania', 'NPL': 'Asia', 'NLD': 'Europe', 'NZL': 'Oceania', 'NIC': 'North America', 'NER': 'Africa', 'NGA': 'Africa', 'PRK': 'Asia', 'MKD': 'Europe', 'NOR': 'Europe', 'OMN': 'Asia', 'PAK': 'Asia', 'PLW': 'Oceania', 'PSE': 'Asia', 'PAN': 'North America', 'PNG': 'Oceania', 'PRY': 'South America', 'PER': 'South America', 'PHL': 'Asia', 'POL': 'Europe', 'PRT': 'Europe', 'QAT': 'Asia', 'ROU': 'Europe', 'RUS': 'Europe', 'RWA': 'Africa', 'KNA': 'North America', 'LCA': 'North America', 'VCT': 'North America', 'WSM': 'Oceania', 'SMR': 'Europe', 'STP': 'Africa', 'SAU': 'Asia', 'SEN': 'Africa', 'SRB': 'Europe', 'SYC': 'Africa', 'SLE': 'Africa', 'SGP': 'Asia', 'SVK': 'Europe', 'SVN': 'Europe', 'SLB': 'Oceania', 'ZAF': 'Africa', 'KOR': 'Asia', 'SSD': 'Africa', 'ESP': 'Europe', 'LKA': 'Asia', 'SDN': 'Africa', 'SUR': 'South America', 'SWE': 'Europe', 'CHE': 'Europe', 'SYR': 'Asia', 'TJK': 'Asia', 'TZA': 'Africa', 'THA': 'Asia', 'TGO': 'Africa', 'TON': 'Oceania', 'TTO': 'North America', 'TUN': 'Africa', 'TUR': 'Asia', 'TKM': 'Asia', 'TUV': 'Oceania', 'UGA': 'Africa', 'UKR': 'Europe', 'ARE': 'Asia', 'GBR': 'Europe', 'USA': 'North America', 'URY': 'South America', 'UZB': 'Asia', 'VUT': 'Oceania', 'VEN': 'South America', 'VNM': 'Asia', 'YEM': 'Asia', 'ZMB': 'Africa', 'ZWE': 'Africa'}

# %%
diccionario_continentes['TLS'] = 'Asia'
print(diccionario_continentes)
# Out:
# {'AFG': 'Asia', 'ALB': 'Europe', 'DZA': 'Africa', 'AND': 'Europe', 'AGO': 'Africa', 'ATG': 'North America', 'ARG': 'South America', 'ARM': 'Asia', 'AUS': 'Oceania', 'AUT': 'Europe', 'AZE': 'Asia', 'BHS': 'North America', 'BHR': 'Asia', 'BGD': 'Asia', 'BRB': 'North America', 'BLR': 'Europe', 'BEL': 'Europe', 'BLZ': 'North America', 'BEN': 'Africa', 'BTN': 'Asia', 'BOL': 'South America', 'BIH': 'Europe', 'BWA': 'Africa', 'BRA': 'South America', 'BRN': 'Asia', 'BGR': 'Europe', 'BFA': 'Africa', 'BDI': 'Africa', 'KHM': 'Asia', 'CMR': 'Africa', 'CAN': 'North America', 'CPV': 'Africa', 'CAF': 'Africa', 'TCD': 'Africa', 'CHL': 'South America', 'CHN': 'Asia', 'COL': 'South America', 'COM': 'Africa', 'COG': 'Africa', 'CRI': 'North America', 'CIV': 'Africa', 'HRV': 'Europe', 'CUB': 'North America', 'CYP': 'Asia', 'CZE': 'Europe', 'COD': 'Africa', 'DNK': 'Europe', 'DJI': 'Africa', 'DMA': 'North America', 'DOM': 'North America', 'ECU': 'South America', 'EGY': 'Africa', 'SLV': 'North America', 'GNQ': 'Africa', 'ERI': 'Africa', 'EST': 'Europe', 'SWZ': 'Africa', 'ETH': 'Africa', 'FJI': 'Oceania', 'FIN': 'Europe', 'FRA': 'Europe', 'GAB': 'Africa', 'GMB': 'Africa', 'GEO': 'Asia', 'DEU': 'Europe', 'GHA': 'Africa', 'GRC': 'Europe', 'GRD': 'North America', 'GTM': 'North America', 'GIN': 'Africa', 'GNB': 'Africa', 'GUY': 'South America', 'HTI': 'North America', 'HND': 'North America', 'HKG': 'Asia', 'HUN': 'Europe', 'ISL': 'Europe', 'IND': 'Asia', 'IDN': 'Asia', 'IRN': 'Asia', 'IRQ': 'Asia', 'IRL': 'Europe', 'ISR': 'Asia', 'ITA': 'Europe', 'JAM': 'North America', 'JPN': 'Asia', 'JOR': 'Asia', 'KAZ': 'Asia', 'KEN': 'Africa', 'KIR': 'Oceania', 'KWT': 'Asia', 'KGZ': 'Asia', 'LAO': 'Asia', 'LVA': 'Europe', 'LBN': 'Asia', 'LSO': 'Africa', 'LBR': 'Africa', 'LBY': 'Africa', 'LIE': 'Europe', 'LTU': 'Europe', 'LUX': 'Europe', 'MDG': 'Africa', 'MWI': 'Africa', 'MYS': 'Asia', 'MDV': 'Asia', 'MLI': 'Africa', 'MLT': 'Europe', 'MHL': 'Oceania', 'MRT': 'Africa', 'MUS': 'Africa', 'MEX': 'North America', 'MDA': 'Europe', 'MNG': 'Asia', 'MNE': 'Europe', 'MAR': 'Africa', 'MOZ': 'Africa', 'MMR': 'Asia', 'NAM': 'Africa', 'NRU': 'Oceania', 'NPL': 'Asia', 'NLD': 'Europe', 'NZL': 'Oceania', 'NIC': 'North America', 'NER': 'Africa', 'NGA': 'Africa', 'PRK': 'Asia', 'MKD': 'Europe', 'NOR': 'Europe', 'OMN': 'Asia', 'PAK': 'Asia', 'PLW': 'Oceania', 'PSE': 'Asia', 'PAN': 'North America', 'PNG': 'Oceania', 'PRY': 'South America', 'PER': 'South America', 'PHL': 'Asia', 'POL': 'Europe', 'PRT': 'Europe', 'QAT': 'Asia', 'ROU': 'Europe', 'RUS': 'Europe', 'RWA': 'Africa', 'KNA': 'North America', 'LCA': 'North America', 'VCT': 'North America', 'WSM': 'Oceania', 'SMR': 'Europe', 'STP': 'Africa', 'SAU': 'Asia', 'SEN': 'Africa', 'SRB': 'Europe', 'SYC': 'Africa', 'SLE': 'Africa', 'SGP': 'Asia', 'SVK': 'Europe', 'SVN': 'Europe', 'SLB': 'Oceania', 'ZAF': 'Africa', 'KOR': 'Asia', 'SSD': 'Africa', 'ESP': 'Europe', 'LKA': 'Asia', 'SDN': 'Africa', 'SUR': 'South America', 'SWE': 'Europe', 'CHE': 'Europe', 'SYR': 'Asia', 'TJK': 'Asia', 'TZA': 'Africa', 'THA': 'Asia', 'TGO': 'Africa', 'TON': 'Oceania', 'TTO': 'North America', 'TUN': 'Africa', 'TUR': 'Asia', 'TKM': 'Asia', 'TUV': 'Oceania', 'UGA': 'Africa', 'UKR': 'Europe', 'ARE': 'Asia', 'GBR': 'Europe', 'USA': 'North America', 'URY': 'South America', 'UZB': 'Asia', 'VUT': 'Oceania', 'VEN': 'South America', 'VNM': 'Asia', 'YEM': 'Asia', 'ZMB': 'Africa', 'ZWE': 'Africa', 'TLS': 'Asia'}

# %%
data_merged['Continent'] = data_merged['Code'].map(diccionario_continentes)

data_merged
# Out:
#             Entity Code  Year  Expected Years of Schooling (years)  \
# 0      Afghanistan  AFG  1990                                  2.6
# 1      Afghanistan  AFG  1991                                  2.9
# 2      Afghanistan  AFG  1992                                  3.2
# 3      Afghanistan  AFG  1993                                  3.6
# 4      Afghanistan  AFG  1994                                  3.9
# ...            ...  ...   ...                                  ...
# 11023     Zimbabwe  ZWE  2013                                 10.2
# 11024     Zimbabwe  ZWE  2014                                 10.3
# 11025     Zimbabwe  ZWE  2015                                 10.3
# 11026     Zimbabwe  ZWE  2016                                 10.3
# 11027     Zimbabwe  ZWE  2017                                 10.3
#
#        GNI per capita, PPP (constant 2017 international $)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11023                                        2875.757148
# 11024                                        2901.298513
# 11025                                        2858.616749
# 11026                                        2884.156050
# 11027                                        3207.887558
#
#        Human Development Index (UNDP)  Population (historical estimates)  \
# 0                                 NaN                         12412311.0
# 1                                 NaN                         13299016.0
# 2                                 NaN                         14485543.0
# 3                                 NaN                         15816601.0
# 4                                 NaN                         17075728.0
# ...                               ...                                ...
# 11023                           0.516                         13350378.0
# 11024                           0.525                         13586710.0
# 11025                           0.529                         13814642.0
# 11026                           0.532                         14030338.0
# 11027                           0.535                         14236599.0
#
#       Continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
# ...         ...
# 11023    Africa
# 11024    Africa
# 11025    Africa
# 11026    Africa
# 11027    Africa
#
# [11028 rows x 8 columns]

# %%
print(data_merged[data_merged['Year'] > 1990].count(), "\n")
print(data_merged.isnull().sum(), "\n")
# Out:
# Entity                                                 10856
# Code                                                    4952
# Year                                                   10856
# Expected Years of Schooling (years)                    10856
# GNI per capita, PPP (constant 2017 international $)     9266
# Human Development Index (UNDP)                         10501
# Population (historical estimates)                      10118
# Continent                                               4952
# dtype: int64
#
# Entity                                                    0
# Code                                                   5904
# Year                                                      0
# Expected Years of Schooling (years)                       0
# GNI per capita, PPP (constant 2017 international $)    1679
# Human Development Index (UNDP)                          385
# Population (historical estimates)                       738
# Continent                                              5904
# dtype: int64
